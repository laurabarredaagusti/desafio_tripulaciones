# %%
import pandas as pd

# %%
# dishwashers=pd.read_csv('csvs_categorias(Columnas BIEN)/1_dishwashers.csv')
# washers=pd.read_csv('csvs_categorias(Columnas BIEN)/2_washers.csv')
# tv_mon=pd.read_csv('csvs_categorias(Columnas BIEN)/3_washers.csv')

# %%
def quitar_aux_marcas(aux_marcas, df):
    for marca in aux_marcas:
        df['Brand'] = df['Brand'].str.replace(marca,'')
    return df

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">1 Lavavajillas

# %%
dishwashers=pd.read_csv('csvs_categorias(Columnas BIEN)/1_dishwashers.csv', index_col=0)
dishwashers.head(1)
# Out:
#          Type     Brand            Model  \
# 0  Dishwasher   Iberna    IDIH 2L952-80
#
#                                     Type_consumption Consumption  \
# 0  Energy consumption [per 100 cycles, based on t...          70
#
#                                                Label  Other
# 0  https://eprel.ec.europa.eu/assets/images/label...      9

# %%
# quitar primer espacio
# dishwashers['Consumption'] = dishwashers['Consumption'].apply(lambda x: x[1:])

# %%
# dishwashers['Consumption'].unique()

# %%
# dishwashers.head(1)

# %%
# quitar nulo, outliers y pasar a float
# dishwashers.drop(dishwashers[dishwashers['Consumption']=='-'].index, inplace=True)
# dishwashers['Consumption']=dishwashers['Consumption'].astype(float)
# mask1 = (dishwashers['Consumption']<30)
# mask2 = (dishwashers['Consumption']>300)
# dishwashers.drop(dishwashers[mask1 | mask2].index, inplace=True)

# %%
# dishwashers['Consumption'].unique()

# %% [markdown]
# ----
# BRANDS

# %%
print('Longitud con mayus y  minus', len(dishwashers['Brand'].unique()))
# Pasar a minúsculas
dishwashers["Brand"]= dishwashers["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(dishwashers['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, dishwashers)

marcas=dishwashers['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 361
# Marcas totales en minúsculas : 324
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 305

# %%
new_marcas
# Out:
# {'adamson',
#  'aeg',
#  'airlux',
#  'akai',
#  'altus',
#  'amica',
#  'amzchef',
#  'andersson',
#  'arctic',
#  'arielli',
#  'aro',
#  'arthur martin',
#  'artica',
#  'asko',
#  'aspes',
#  'atag',
#  'atlantic',
#  'aya',
#  'balay',
#  'bauknecht',
#  'baumatic',
#  'becken',
#  'beko',
#  'benavent',
#  'berk',
#  'berklays',
#  'bertazzoni',
#  'blaupunkt',
#  'blitzhome',
#  'blokker',
#  'blomberg',
#  'bolero aguazero',
#  'bomann',
#  'bora',
#  'bosch',
#  'brandt',
#  'brandy best',
#  'bright',
#  'burg',
#  'burg basic',
#  'bush',
#  'candy',
#  'caple',
#  'cata',
#  'cda',
#  'cecotec',
#  'cobal',
#  'coldis',
#  'comfee',
#  'comfee`',
#  'concept',
#  'confortec',
#  'constructa',
#  'continental edison',
#  'cooke & lewis',
#  'corbero',
#  'cranker',
#  'crown',
#  'curtiss',
#  'cylinda',
#  'daewoo',
#  'dalbach',
#  'davoline',
#  'de dietrich',
#  "de'longhi",
#  'decobus handel',
#  'dellonda (eu)',
#  'delonghi',
#  'dieter knoll',
#  'domeos',
# ...

# %%
''' 
QUITAR
'guang dong mei zhi dian qi ke ji you xian gong si'


'burg' = 'burg basic' 
'comfee' = 'comfee`'
'delonghi' = "de'longhi"
'hotpoint' = 'hotpoint/ariston'
'ikea' = 'ikea of sweden'
'lg' = 'lg electronics','lg electronics inc.'
'ok' = 'ok.'
'xd' = 'xd grandi elettrodomestici'

'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">2 Lavadoras

# %%
washers=pd.read_csv('csvs_categorias(Columnas BIEN)/2_washers.csv',index_col=0)
washers.head(1)
# Out:
#      Type      Brand           Model  \
# 0  Washer   Samsung    WW11BB945DGM
#
#                                     Type_consumption  Consumption  \
# 0  Weighted energy consumption [per 100 cycles, e...           48
#
#                                                Label Other
# 0  https://eprel.ec.europa.eu/assets/images/label...    11

# %%
print('Longitud con mayus y  minus', len(washers['Brand'].unique()))
# Pasar a minúsculas
washers["Brand"]= washers["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(washers['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, washers)

marcas=washers['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 395
# Marcas totales en minúsculas : 344
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 317

# %%
'''
QUITAR
'nanjing chuangwei household electronic appliances limited'

CAMBIAR

'bolero' = 'bolero dresscode', 'bolero wash&dry'
'midea' = 'brand - midea'
'corbero' = 'corberó'
'delonghi' = "de'longhi"
'denner' = 'denner-edition'
'electrolux' = 'electrolux professional'
'hisense' = 'hisense_gor'
'hotpoint' = 'hotpoint/ariston'
'lg' = 'lg electronics', 'lg eelectronics', 'lg electronics inc.'
'little swan international' = 'little swan international(singapore) co., pte. ltd'
'midea' = 'midea'
'miele' = 'miele & cie kg'
'montpellier domestic appliances' = 'montpellier domestic aplliances'
'ok' = 'ok.'
'osby' = 'osby vitvaror ab'
'otsein' = 'otsein-hoover'
'schulthess' = 'schulthess maschinen ag'

'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">3 TV/Monitores

# %%
tv_mon=pd.read_csv('csvs_categorias(Columnas BIEN)/3_tv_monitors.csv',index_col=0)
tv_mon.head(1)
# Out:
#          Type                 Brand           Model Type_consumption  \
# 0  TV/Monitor   IIYAMA CORPORATION    GB2770HSU-B5                 W
#
#   Consumption                                              Label Other
# 0        18,8  https://eprel.ec.europa.eu/assets/images/label...   SDR

# %% [markdown]
# -----

# %%
print('Longitud con mayus y  minus', len(tv_mon['Brand'].unique()))
# Pasar a minúsculas
tv_mon["Brand"]= tv_mon["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(tv_mon['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, tv_mon)

marcas=tv_mon['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 473
# Marcas totales en minúsculas : 426
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 403

# %%
'''
'a.i.o.' =
        'a.i.o. evo hd led tv ultrawide 18,5" (für manuelle antennen) mit integriertem satfinder',
        'a.i.o. evo hd led tv ultrawide 18,5" (mit integrierter antennensteuerung)',
        'a.i.o. evo hd led tv ultrawide 22" (für manuelle antennen) mit integriertem satfinder',
        'a.i.o. evo hd led tv ultrawide 22" (mit integrierter antennensteuerung)',
        'a.i.o. evo hd led tv ultrawide 24" (für manuelle antennen) mit integriertem satfinder',
        'a.i.o. evo hd led tv ultrawide 24" (mit integrierter antennensteuerung)'
'abus' = 'abus security center led monitor'
'adesa' = 'adesa s.r.l.', 'adesas.r.l.'
'alphatronics' ='alphatronics gmbh '
'digihome'='digihome(gb-ie)'
'digiquest solution srl' = 'digiquest solutions srl', 'digiquest solutions surl'
'digital smart vision = 'digital smart vision / npg'
'dyon' = 'dyon - dyon'
'eas electric' = 'eas electric smart technology'
QUITAR 'em 009055716 - lc-power'
'fox' = 'fox spirit'
'hanns g'= 'hanns·g',  'hanns`g'
'hkc' = 'hkc.'
'hp' = 'hp, inc.'
'inno hit' = 'inno hit pro'
'jtc' = 'jtc / jay-tech gmbh'
QUITAR
        'led tv smartwide 19" / dvb-s2, dvb-t2, dvb-c /  bluetooth',
        'led tv smartwide 22" / dvb-s2, dvb-t2, dvb-c /  bluetooth',
        'led tv smartwide 24" / dvb-s2, dvb-t2, dvb-c /  bluetooth',
        'led tv smartwide 32"',
        'led tv ultrawide 18,5" / dvb-s2, dvb-t2, dvb-c / dvd-player',
        'led tv ultrawide 22"   / dvb-s2, dvb-t2, dvb-c / dvd-player',
        'led tv ultrawide 24"   / dvb-s2, dvb-t2, dvb-c / dvd-player'
'lg' = 'lg eelectronics', 'lg electronics', 'lg electronics inc.'
'luxor' = 'luxor (v.uk)'
'megasat' = 'megasat/tv'
'newline' = 'newline interactive inc./ newline'
'ok' = 'ok.'
'ricoh' = 'ricoh company,ltd.'
'sampo' = 'sampo corporation'
'shark gaming' = 'shark gaming systems', 'sharkgaming'
'techwood' = 'techwood(gb)'
'tesla' = 'tesla smart'
'tkh' = 'tkh security france sas'
'unv technology' = 'unv technology europe b.v.'
'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">4 Frigoríficos y congeladores

# %%
frid_freez=pd.read_csv('csvs_categorias(Columnas BIEN)/4_fridges_freezers.csv',index_col=0)
frid_freez.head(1)
# Out:
#              Type    Brand         Model           Type_consumption  \
# 0  Fridge/Freezer   OCEAN    CB 290 W 2   Annual energy consumption
#
#   Consumption                                              Label Other
# 0         280  https://eprel.ec.europa.eu/assets/images/label...   204

# %%
print('Longitud con mayus y  minus', len(frid_freez['Brand'].unique()))
# Pasar a minúsculas
frid_freez["Brand"]= frid_freez["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(frid_freez['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, frid_freez)

marcas=frid_freez['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 1050
# Marcas totales en minúsculas : 946
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 869

# %%
'''
QUITAR
'-'
'02028 maxxmee elektro kühlbox'
'07949 fcb kühlschrank'
'213391 - powerpoint'
'3324092'
'6'
'beijingjunxingmingwangkejiyouxiangongsi'
'electronic cooler/warmer    (kue002sz，kue002dgr，kue002bl，kue002gn)',
'electronic cooler/warmer （kue003sz，kue003gr，kue003bl）'
'flaschenkühlschrank 270ln',
'flaschenkühlschrank 88l',
'flaschenkühlschrank 88l,28fl',
'flaschenkühlschrank, 270ln'
'forgast 40-780 katowice owsiana 58a'
'hs-60wn'
'kc-50l',
'kc-75',
'l2g'
'qingdaohuituyuhongshangmaoyouxiangongsi',
'r.d.i. deutschland autoteile + zubehör'
'tiefkühlschrank 200ln',
'tiefkühlschrank tks38',
'tiefkühltruhe 252lw',
'tiefkühltruhe 368lw',
'tiefkühltruhe 458lw',
'weinkühlschrank 2z 126fl',
'weinkühlschrank 2z 180fl',
'weinkühlschrank 2z 38fl',
'weinkühlschrank 2z 40fl'
'yt-a-24xb'

CAMBIAR
'arka' = 'arka agd sp. z o.o. / electroline'
'aviro' = 'aviro minibar 24 l','aviro minibar 30 l','aviro minibar 40 l'
'bermar' = 'bermar (international)'
'bilancia exim' = 'bilanciaexim'
'blokker' = 'blokker b.v.'
'bodega' = 'bodega43'
'bompani' = 'bompani - bompani', 'bomppani'
'carwise' = 'carwise - bileko car parts ab'
'casa design' = 'caso design', 'caso-design'
'corbero' = 'corberó'
'cubes' = '°cubes'
'delonghi' = "de'longhi"
'domo' = 'domo kamado'
'dosenbach ochsner' ='dosenbach   ochsner ag','dosenbach - ochsner ag'
'eas electric smart technology' = 'ref001 - eas electric smart technology'
'electrolux' = 'electrolux professional'
'essentiel b' = 'essentielb'
'guangdong unique' = 'guangdong unique appl. co.'
'hartmann tresore' = 'hartmann tresore france'
'hck fridge'='hck refrigeration tech.co.,ltd'
'helle kylmäarkku'= 'helle kylmäarkku 15l','helle kylmäarkku 52l'
'hermitage' = 'hermitag',
'hisense' = 'hisense international (hong kong) europe investment'
'hitachi' = 'hitachi europe'
'hotpoint' = 'hotpoint/ariston'
'haeger'='hæger'
'ikea' = 'ikea of sweden ab'
'ism' = 'ism makine elektrik san. ve tic. a.s.', 'ism minibar'
'kams' = 'kams sarl'
'kbs gastroetechnik' = 'kbs gastrotechnik', 'kbs gastrotechnink', 'kbs-gastrotechnik'
'kesser' = 'kesser ®'
'kontinent' = 'kontinent deluxe'
'lamo' = 'lamo bd-80u', 'lamo/pyramidea'
'lg' = 'lg eelectronics', 'lg electronics'
'life' = 'life outdoor living'
'magira' = 'magira®'
'marshall' = 'marshall fridge'
'midea' = 'midea polska'
'minibar' = 'minibar 34l', 'minibar 34l-gl', 'minibar alda bc30', 'minibar alda bc40', 'minibar enterprises ag'
'montpellier domestic appliance' = 'montpellier domestic appliances'
'mountfield bcw' = 'mountfield bcw - 25a', 'mountfield bcw - 49'
'nara hladilna tehnika d.o.o.' = 'nara hladilna thenika d.o.o.'
'ok' = 'ok.'
'omnitec' = 'omnitec systems'
'penta' = 'penta cz s.r.o.',m'penta cz, s.r.o.'
'qingdao smad electric appliances' = 'qingdao smad electric appliances co'
'severin elektrogeräte' = 'severin elektrogräte'
'signature' = 'signature kitchen suite'
'snaige' = 'snaigė'
'temptech' = 'temptech as'
'thetaco' = 'thetaco traders'
'vestfrost', 'vestfrost solutions'
'vintage industries / gastro-cool' = 'vintage industries/gastro-cool'
'wemo' = 'wemo hc30', 'wemo hc40'
'xd' = 'xd grandi elettrodomestici'

'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">5 Hornos

# %%
ovens=pd.read_csv('csvs_categorias(Columnas BIEN)/5_ovens.csv',index_col=0)
ovens.head(1)
# Out:
#    Type    Brand        Model Type_consumption  Consumption  \
# 0  Oven   Candy    FIDC N686         kWh/ciclo         0.89
#
#                                                Label  Other
# 0  https://eprel.ec.europa.eu/assets/images/label...     70

# %%
print('Longitud con mayus y  minus', len(ovens['Brand'].unique()))
# Pasar a minúsculas
ovens["Brand"]= ovens["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(ovens['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, ovens)

marcas=ovens['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 305
# Marcas totales en minúsculas : 272
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 252

# %%
'''
QUITAR
'bic8 gk-2kb ix4',
'f7-2x'


CAMBIAR
'burg' = 'burg basic'
'cookers' = 'cookers - bompani', 'cookers - doman', 'cookers - kontact', 'cookers - proline', 'cookers - triomph', 'cookers kontact'
'de longhi' = 'de longhi', "de'longhi"
'dieter knoll' =  'dieter knoll collection'
'electra' = 'electra +'
'good home' = 'goodhome'
'juro-pro' = 'ovens - jro-pro', 'ovens - juro-pro'
'kingfisher' = 'kingfisher rnational cts limited'
'kontinent' = 'kontinent deluxe'
'la germania' = 'lagermania 1882'
'lg' = 'lg electronics inc.'
'miele & cie kg' = 'miele & cie. kg'
'neue' = 'neue by candy'
'new pol' = 'newpol'
'ok' = 'ok.'
'whirlpool' = 'whirlpool emea spa'



'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">6 Campanas

# %%
campanas=pd.read_csv('csvs_categorias(Columnas BIEN)/6_campanas.csv',index_col=0)
campanas.head(1)
# Out:
#           Type     Brand      Model          Type_consumption Consumption  \
# 0  Range hoods   Pitsos    2MID60T   Consumo anual de energía        37,9
#
#                                                Label  Other
# 0  https://eprel.ec.europa.eu/assets/images/label...    NaN

# %%
wh=(37.9*1000)/365
print('wh',wh)
precio_luz=0.20183/1000
print('precio luz wh',precio_luz)
print('euros',wh*precio_luz )
# Out:
# wh 103.83561643835617
# precio luz wh 0.00020183
# euros 0.020957142465753427

# %%
print('Longitud con mayus y  minus', len(campanas['Brand'].unique()))
# Pasar a minúsculas
campanas["Brand"]= campanas["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(campanas['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, campanas)

marcas=campanas['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 416
# Marcas totales en minúsculas : 394
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 380

# %%
new_marcas
# Out:
# {'6004w',
#  '6090-2h',
#  '6090y',
#  '6091h',
#  '6091h-kf',
#  '8060gz',
#  '8090gz',
#  '8099gis z',
#  '8099is z',
#  '8888w',
#  '9004w',
#  '9031x',
#  '9039x',
#  '9039xw',
#  '9039y',
#  '9040-60bz',
#  '9040-60wz',
#  '9040-90 bz',
#  '9040-90wz',
#  '9040/90bz',
#  '9040/90wz',
#  '9041-60 xbg',
#  '9041-80xbg',
#  '9060bh',
#  '9060wh',
#  '9080bz',
#  '9080wz',
#  '9090 isz',
#  '9090-2h',
#  '9860lz',
#  '9878lz',
#  '9999-2h',
#  'aeg',
#  'afrelli',
#  'aga',
#  'aga rangemaster',
#  'air force',
#  'airforce',
#  'airone',
#  'akpo',
#  'amica',
#  'amsta',
#  'apell',
#  'apell spa',
#  'arctic',
#  'arielli',
#  'ariston',
#  'arthur martin',
#  'asko',
#  'aspes',
#  'atag',
#  'atlantic',
#  'aya',
#  'balay',
#  'basic line',
#  'bauknecht',
#  'baumatic',
#  'becken',
#  'beko',
#  'benthaus',
#  'berbel',
#  'berbel ablufttechnik',
#  'best',
#  'birnstiel',
#  'blaupunkt',
#  'bomann',
#  'bompani',
#  'bompani - bompani',
#  'bora',
#  'bosch',
#  'brandt',
# ...

# %%
'''
QUITAR
'6004w',
 '6090-2h',
 '6090y',
 '6091h',
 '6091h-kf',
 '8060gz',
 '8090gz',
 '8099gis z',
 '8099is z',
 '8888w',
 '9004w',
 '9031x',
 '9039x',
 '9039xw',
 '9039y',
 '9040-60bz',
 '9040-60wz',
 '9040-90 bz',
 '9040-90wz',
 '9040/90bz',
 '9040/90wz',
 '9041-60 xbg',
 '9041-80xbg',
 '9060bh',
 '9060wh',
 '9080bz',
 '9080wz',
 '9090 isz',
 '9090-2h',
 '9860lz',
 '9878lz',
 '9999-2h'
 'fs1-60bspy'
 'gsi-60cixph'
 'i2-70+btz',
 'i2-70+wtz',
 'i3-40a+btz',
 'i3-40a+wtz',
 'kh-60kh-s',
 'kh-gsh-60b',
 'kh-msh-60b',
 'khu-601',
 'khu-602',
 'khu-602-h',
 'khu-603',
 'khu-60eb'
 's13-60 bbpy',
 's2-60 abtz',
 's2-90abtz',
 's20-60 abty',
 's20-60 awty',
 's20-60 awtz',
 's20-60abtz',
 's20-90 abty',
 's20-90 awty',
 's22-60 bbpy',
 's23-60 abpx',
 's25-60 abth',
 's25-60 awth',
 's25-90 abth',
 's25-90 awth',
 's26-50 bbty',
 's26-60 bbty',
 's26-60 bwty',
 's26-90 bbty',
 's26-90 bwty',
 's27-60abty',
 's27-60awty',
 's27-90a+bty',
 's27-90a+wty',
 's3-60 abtz',
 's3-90 abtz',
 's5-80 bbex',
 's7-60 abth',
 's7-60 awth',
 's7-90abth',
 's7-90awth',
 's9-60 abtz',
 's9-80 abtz'
 'sh-a60-bl',
 'sh60-bl',
 'sh60-ix',
 'sh60-ixg',
 'sh60-wh',
 'sl i3-40a+sstz',
 'sl i4-90a++ixtz',
 'sl p1-60a ixez',
 'sl p1-90a+ixez',
 'sl s4-60a++btz',
 'sl s4-60a++wtz',
 'sl s4-90a++btz',
 'sl s4-90a++wtz',
 'sl s5-60 abtz',
 'sl s5-60 awtz',
 'sl s5-80 abtz',
 'sl s5-80 awtz',
 'sl t2-60a++ixtz',
 'sl t2-90a++ixtz',
 'sl10-60 abtz',
 'sl10-90 abtz'
 'supplier name or trademark',
 't1-60 a++ ixez',
 't1-90 a++ixez',
 'ubh3001x',
 'ubh4060-2h',
 'ubh5000h',
 'ubh5000h2',
 'ubh6002-2h',

CAMBIAR
 'aga' = 'aga rangemaster'
 'air force' = 'airforce'
 'apell' = 'apell spa'
 'berbel' = 'berbel ablufttechnik'
 'bompani' ='bompani - bompani'
 'cata' = 'cata electrodomésticos', 'cata electrodomésticos s.l', 'cata electrodomésticos s.l.'
 'ciarko' ='ciarko design'
 'corbero' = 'corberó'
 'delta' = 'delta 60 bl a evo', 'delta 60 px a evo', 'delta 60 wh a evo'
 'delonghi' = "de'longhi"
 'dieter knoll' = 'dieter knoll collection'
 'eurolux' = 'eurolux by faber'
 'good home' = 'goodhome'
 'husqvarna' = 'husqvarna-electrolux'
 'kingfisher' = 'kingfisher rnational cts limited'
 'miele' = 'miele & cie kg'
 'neue' = 'neue by candy'
 'novy' = 'novy panorama power 1841'
 'ok' = 'ok.'
 'roroshetta' = 'røroshetta'
 'sil fim' = 'silfim'



'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">7 Calentador de agua

# %%
calentador=pd.read_csv('csvs_categorias(Columnas BIEN)/7_water_heaters.csv',index_col=0)
calentador.head(1)
# Out:
#             Type      Brand                Model  \
# 0  Water heaters   Rossato    AIR COMBO EVO 300
#
#                 Type_consumption Consumption  \
# 0  Consumo anual de electricidad       1 361
#
#                                                Label Other
# 0  https://eprel.ec.europa.eu/assets/images/label...    XL

# %%
print('Longitud con mayus y  minus', len(calentador['Brand'].unique()))
# Pasar a minúsculas
calentador["Brand"]= calentador["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(calentador['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, calentador)

marcas=calentador['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 90
# Marcas totales en minúsculas : 90
# Marcas sin espacios principio y fin: 90
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_marcas
# Out:
# {'acv',
#  'aeg',
#  'aeg haustechnik',
#  'alpha innotec',
#  'aquastic',
#  'ariston',
#  'atag',
#  'atlantic',
#  'baxi spa',
#  'beretta',
#  'bosch',
#  'buderus',
#  'bulex',
#  'chaffoteaux',
#  'chappee',
#  'climer',
#  'clivet',
#  'cordivari',
#  'cosmogas',
#  'daikin',
#  'de dietrich',
#  'dimplex',
#  'družstevní závody dražice - strojírna',
#  'eca technology',
#  'ekallor',
#  'elco',
#  'eldom',
#  'elíz',
#  'emmeti',
#  'energia w kogeneracji ewk s.a.',
#  'ferroli',
#  'flexit as',
#  'fondital',
#  'fröling heizkessel- und behälterbau ges.m.b.h.',
#  'galanta',
#  'galmet',
#  'gorenje',
#  'gree',
#  'haier',
#  'hajdu',
#  'hoval',
#  'immergas',
#  'inventum',
#  'invest living',
#  'italtherm',
#  'itho daalderop',
#  'junkers',
#  'kermi',
#  'kospel s.a.',
#  'kronoterm',
#  'kwb - kraft und wärme aus biomasse',
#  'kwb kraft und wärme aus biomasse',
#  'lamborghini caloreclima',
#  'lg electronics',
#  'max weishaupt',
#  'maxa',
#  'metro therm',
# ...

# %%
''' 
QUITAR
'družstevní závody dražice - strojírna'
'kwb - kraft und wärme aus biomasse', 
'kwb kraft und wärme aus biomasse'

CAMBIAR
'ewk' ='energia w kogeneracji ewk s.a.'
'froling' = 'fröling heizkessel- und behälterbau ges.m.b.h.'
'metrotherm' = 'metro therm',
'mitsubishi' = 'mitsubishi electric' , 'mitsubishi heavy industries'
'toshiba' = 'toshiba carrier corporation'
'remko' = 'trademark - remko'



'''

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">8 Luces

# %%
lights=pd.read_csv('csvs_categorias(Columnas BIEN)/8_lights.csv',index_col=0)
lights.head(1)
# Out:
#     Type       Brand             Model               Type_consumption  \
# 0  Light   AIGOSTAR    701QKT-15-40-G   Energy consumption in on-mode
#
#   Consumption                                              Label   Other
# 0          15  https://eprel.ec.europa.eu/assets/images/label...   1 200

# %%
print('Longitud con mayus y  minus', len(lights['Brand'].unique()))
# Pasar a minúsculas
lights["Brand"]= lights["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(lights['Brand'].unique()))

aux_marcas = [r'\ufeff', 'a/s','int.','prod.','b.v.',' co.,ltd.','ind.co.,ltd', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.','s.r.o.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, lights)

marcas=lights['Brand'].unique()
marcas.sort()

new_marcas=[]
for marca in marcas:
    new_marcas.append(marca.strip())
new_marcas.sort()   
# new_marcas=set(new_marcas)
print('Marcas sin espacios principio y fin:',len(new_marcas))
# Out:
# Longitud con mayus y  minus 2888
# Marcas totales en minúsculas : 2833
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Marcas sin espacios principio y fin: 2729

# %%
new_marcas
# Out:
# ['',
#  '',
#  '" changning jiexin technology co.  "',
#  '" citizen electronics co. "',
#  '" seoul semiconductor co.ltd "',
#  '" shenzhenshi youmate technology co."',
#  '" zhongshan zhongxiang lighting co. "',
#  '-',
#  '021a-5000-30-608',
#  '1 primer leader',
#  '2r',
#  '3dyycx',
#  '4k5',
#  '4vwin',
#  '4x light',
#  '7h dayron',
#  '7h sevenon',
#  '8 seasons',
#  'a led',
#  'a lighting',
#  'a-collection',
#  'a.l.s.',
#  'a.t.lums',
#  'ab',
#  'ab living light',
#  'abc sistem',
#  'abishion',
#  'absolu chic',
#  'ac-bernes s.l',
#  'acebon',
#  'acec',
#  'acegoo',
#  'aceon',
#  'acorn solutions',
#  'actioled',
#  'activeallbrite',
#  'adakat',
#  'addlive',
#  'addlon',
#  'adeo services',
#  'adluminis',
#  'adrilux polska sp. z o. o.',
#  'aeg',
#  'aeoss',
#  'aerfa',
#  'aerospot',
#  'aetkfo',
#  'agata sa',
#  'agc lighting',
#  'agolar',
#  'agolux',
#  'agotd',
#  'aiagostar',
#  'aigostar',
#  'aigostar',
#  'ailiebe design',
#  'aimheim',
#  'aio',
# ...

# %% [markdown]
# ---
# ---
# ---
# <font size="7"><span style="color:green">TODO JUNTO

# %%
junto=pd.concat([dishwashers,washers,tv_mon,frid_freez,ovens,campanas,calentador,lights])
junto
# Out:
#              Type       Brand            Model  \
# 0      Dishwasher     iberna    IDIH 2L952-80
# 1      Dishwasher   baumatic    BDIH 2L952-80
# 2      Dishwasher    siemens       SN23HW00ME
# 3      Dishwasher      bosch       SMS4HMI02E
# 4      Dishwasher    siemens       SN23HI00KE
# ...           ...         ...              ...
# 10044       Light   XAL GmbH        000434286
# 10045       Light   XAL GmbH        000335404
# 10046       Light   XAL GmbH        000335667
# 10047       Light   XAL GmbH        000335733
# 10048       Light   XAL GmbH        000335785
#
#                                         Type_consumption Consumption  \
# 0      Energy consumption [per 100 cycles, based on t...          70
# 1      Energy consumption [per 100 cycles, based on t...          70
# 2      Energy consumption [per 100 cycles, based on t...          85
# 3      Energy consumption [per 100 cycles, based on t...          85
# ...

# %%
len(junto['Brand'].unique())
# Out:
# 5035

# %%
# Pasar a minúsculas
junto["Brand"]= junto["Brand"].str.lower() 
  
print('Marcas totales en minúsculas :',len(junto['Brand'].unique()))
# Out:
# Marcas totales en minúsculas : 4461

# %%
def quitar_aux_marcas(aux_marcas, df):
    for marca in aux_marcas:
        df['Brand'] = df['Brand'].str.replace(marca,'')

# %%
aux_marcas = [r'\ufeff', r'\u0101', r'\u0442','a/s',' co.,ltd.', ' co., ltd', '/ipg31', '/ipb30', '/ipb40', ' ltd.', ' s.r.l.', ' s.p.a.', ' srl', ' gmbh']
quitar_aux_marcas(aux_marcas, junto)
# Out:
# c:\Users\Yo\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(junto['Brand'].unique())
# Out:
# 4299

# %%
marcas=junto['Brand'].unique()
marcas.sort()
# marcas.tolist()

# %%
# for brand in junto['Brand']:
#     if brand[0]==' ':
#         junto['Brand'][brand][0]=''

# %%
marcas
# Out:
# array([' ', '  6090y ', '  allesin ', ..., 'lena lighting s.a. ', 'ma ',
#        'ne '], dtype=object)

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
marcas
# Out:
# array([' ', '  6090y ', '  allesin ', '  dahua ', '  digihome(gb-ie) ',
#        '  dina ', '  eterbiz ', '  flsnt ', '  globo handels ',
#        '  green ', '  inspire ', '  khu-602-h    ', '  kommunal kw ',
#        '  mpm ', '  ovens - juro-pro ', '  relco ', '  sh-a60-bl   ',
#        '  shenzhen longtime metals', '  shenzhen xianliang lighting ',
#        '  sia depo diy ', '  ttway ', '  videx ',
#        '  vossloh-schwabe italia ', '  м елком оод ', ' - ',
#        ' 02028 maxxmee elektro kühlbox ', ' 021a-5000-30-608 ',
#        ' 07949 fcb kühlschrank ', ' 1 primer leader ',
#        ' 213391 - powerpoint ', ' 2r ', ' 3324092 ', ' 3dyycx ', ' 4k5 ',
#        ' 4vwin ', ' 4x light ', ' 6 ', ' 6004w ', ' 6090-2h ', ' 6091h ',
#        ' 6091h-kf ', ' 7h dayron ', ' 7h sevenon ', ' 8 seasons ',
#        ' 8060gz ', ' 8090gz ', ' 8099gis z ', ' 8099is z ', ' 8888w  ',
#        ' 9004w ', ' 9031x ', ' 9039x ', ' 9039xw ', ' 9039y ',
# ...
