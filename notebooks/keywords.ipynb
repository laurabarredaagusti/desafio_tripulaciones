# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
onlyfiles = [f for f in listdir('../data') if isfile(join('../data', f))]

# %%
def create_df(files):
    for index, file in enumerate(onlyfiles):
        path = '../data/' + file
        if index == 0:
            df = pd.read_csv(path)
        else:
            df1 = pd.read_csv(path)
            df = pd.concat([df,df1])
    return df

# %%
df = create_df(onlyfiles)

# %%
df.drop(columns=['SERP Features', 'Trend'], inplace=True)

# %%
df = df[df.Volume > 100]

# %%
df = df.sort_values(by=['Volume'], ascending=False)

# %%
words_list = ['genshin', 'honey', 'energía xxi', 'fenie', 'chc', 'deep', 'honkai', 'tna', 'agencia', 'game', 'subito', 'muebles', 'nike', 
              'súbito', 'canarias', 'periódico', 'carrefour', 'dibujo', 'edp', 'endesa', 'guru', 'periodico', 'próxima', 'repsol', 'cooperativa',
              'energes', 'gana']

# %%
def remove_rows(df, list):
    for word in list:
        df = df[df["Keyword"].str.contains(word) == False]
    return df

# %%
df = remove_rows(df, words_list)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                  Keyword  Volume  Keyword Difficulty  CPC (USD)  \
# 0             aerotermia   33100                53.0       0.33
# 1           ahorro total   14800                42.0       0.26
# 2         medio ambiente   12100                79.0       0.70
# 3             ahorra mas    9900                42.0       0.44
# 4  eficiencia energetica    6600                61.0       0.41
#
#    Competitive Density  Number of Results                        Intent
# 0                 1.00       4.350000e+06  Informational, Transactional
# 1                 1.00       8.290000e+07                  Navigational
# 2                 0.01       1.320000e+09                 Informational
# 3                 0.01       7.220000e+07                  Navigational
# 4                 0.18       6.160000e+06     Informational, Commercial

# %%
df_35 = df.head(35)
df_35
# Out:
#                                    Keyword  Volume  Keyword Difficulty  \
# 0                               aerotermia   33100                53.0
# 1                             ahorro total   14800                42.0
# 2                           medio ambiente   12100                79.0
# 3                               ahorra mas    9900                42.0
# 4                    eficiencia energetica    6600                61.0
# 5                                geotermia    6600                41.0
# 6                               eficiencia    6600                55.0
# 7                    eficiencia energetica    6600                61.0
# 8                      energías renovables    6600                62.0
# 9                                 domotica    6600                49.0
# 10                       aerotermia precio    5400                30.0
# 11                     como ahorrar dinero    4400                39.0
# 12                           energía solar    4400                58.0
# 13                       energía renovable    4400                63.0
# 14                                  ahorro    3600                57.0
# 15                                 ahorrar    3600                43.0
# 16                                 energía    3600                84.0
# 17                                  energí    3600                93.0
# 18                    que es la aerotermia    3600                47.0
# 19                   eficiencia y eficacia    2900                44.0
# 20                aerotermia como funciona    2900                45.0
# 21                          energía eólica    2900                49.0
# 22                   eficiencia energética    2900                68.0
# 23               aerotermia con radiadores    2900                24.0
# 24                      aerotermia precios    2900                32.0
# 25                       aerotermia que es    2900                44.0
# 26                       el medio ambiente    2900                68.0
# 27                   eficiencia energética    2900                68.0
# 28                               eficiente    2900                50.0
# 29                         energía nuclear    2900                56.0
# 30  diferencia entre eficiencia y eficacia    2400                39.0
# 31          medio ambiente o medioambiente    2400                39.0
# 32                        másmóvil energía    2400                38.0
# 33          diferencia eficacia eficiencia    2400                41.0
# 34       certificado eficiencia energetica    2400                54.0
#
#     CPC (USD)  Competitive Density  Number of Results  \
# 0        0.33                 1.00       4.350000e+06
# 1        0.26                 1.00       8.290000e+07
# 2        0.70                 0.01       1.320000e+09
# 3        0.44                 0.01       7.220000e+07
# 4        0.41                 0.18       6.160000e+06
# 5        0.26                 0.26       3.850000e+06
# 6        0.22                 0.00       2.370000e+08
# 7        0.41                 0.18       6.160000e+06
# 8        0.47                 0.20       3.100000e+07
# 9        0.25                 0.38       1.430000e+07
# 10       0.44                 1.00       2.320000e+06
# 11       0.29                 0.29       6.040000e+07
# 12       1.18                 0.69       7.860000e+07
# 13       0.47                 0.20       1.780000e+07
# 14       0.55                 0.07       3.200000e+08
# 15       0.55                 0.07       1.200000e+08
# 16       0.79                 0.04       6.940000e+08
# 17       0.65                 0.02       1.360000e+09
# 18       0.17                 0.65       4.420000e+06
# 19       0.12                 0.01       4.740000e+07
# 20       0.18                 0.61       2.160000e+05
# 21       0.34                 0.22       1.020000e+07
# 22       0.41                 0.18       2.790000e+07
# 23       0.39                 1.00       2.110000e+06
# 24       0.44                 1.00       2.040000e+06
# 25       0.17                 0.65       3.860000e+06
# 26       0.70                 0.01       1.220000e+09
# 27       0.41                 0.18       2.790000e+07
# 28       0.22                 0.00       4.380000e+08
# 29       0.06                 0.01       2.330000e+07
# 30       0.07                 0.01       3.900000e+07
# 31       0.00                 0.00       2.250000e+07
# 32       1.28                 0.34       1.480000e+05
# 33       0.07                 0.01       3.110000e+07
# 34       0.74                 0.56       3.750000e+05
#
#                           Intent
# 0   Informational, Transactional
# 1                   Navigational
# 2                  Informational
# 3                   Navigational
# 4      Informational, Commercial
# 5      Informational, Commercial
# 6                  Informational
# 7      Informational, Commercial
# 8                  Informational
# 9                     Commercial
# 10                 Transactional
# 11                 Informational
# 12                    Commercial
# 13                 Informational
# 14                    Commercial
# 15                 Informational
# 16                 Informational
# 17                    Commercial
# 18                 Informational
# 19                 Informational
# 20                 Informational
# 21                 Informational
# 22                 Informational
# 23  Informational, Transactional
# 24                 Transactional
# 25                 Informational
# 26                 Informational
# 27                 Informational
# 28  Informational, Transactional
# 29                 Informational
# 30                 Informational
# 31                 Informational
# 32                  Navigational
# 33                 Informational
# 34     Informational, Commercial

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df_35, x="Volume", y="Keyword")
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Keyword'>

# %%
def keep_rows(df, word):
    df = df[df["Keyword"].str.contains(word)]
    return df

# %%
df_aerotermia = keep_rows(df, 'aerotermia')
df_aerotermia['group'] = 'aerotermia'
df_aerotermia = df_aerotermia.groupby(['group']).sum('Volume')
df_aerotermia = df_aerotermia[['Volume']]
df_aerotermia
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# aerotermia  164770

# %%
df_eficiencia = keep_rows(df, 'eficiencia')
df_eficiencia['group'] = 'eficiencia'
df_eficiencia = df_eficiencia.groupby(['group']).sum('Volume')
df_eficiencia = df_eficiencia[['Volume']]
df_eficiencia.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# eficiencia  139250

# %%
df_etiqueta = keep_rows(df, 'etiqueta')
df_etiqueta['group'] = 'etiqueta'
df_etiqueta = df_etiqueta.groupby(['group']).sum('Volume')
df_etiqueta = df_etiqueta[['Volume']]
df_etiqueta.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Volume
# group
# etiqueta    8710

# %%
df_consumo = keep_rows(df, 'consumo')
df_consumo['group'] = 'consumo'
df_consumo = df_consumo.groupby(['group']).sum('Volume')
df_consumo = df_consumo[['Volume']]
df_consumo.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Volume
# group
# consumo    9400

# %%
df_medioambiente = keep_rows(df, 'medio ambiente')
df_medioambiente['group'] = 'medio ambiente'
df_medioambiente = df_medioambiente.groupby(['group']).sum('Volume')
df_medioambiente = df_medioambiente[['Volume']]
df_medioambiente.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 Volume
# group
# medio ambiente  110150

# %%
geotermia = keep_rows(df, 'geotermia')
geotermia['group'] = 'geotermia'
geotermia = geotermia.groupby(['group']).sum('Volume')
geotermia = geotermia[['Volume']]
geotermia
# Out:
# c:\Users\enriq\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Volume
# group
# geotermia   19410

# %%
domotica = keep_rows(df, 'domotica')
domotica['group'] = 'domotica'
domotica = domotica.groupby(['group']).sum('Volume')
domotica = domotica[['Volume']]
domotica
# Out:
# c:\Users\enriq\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Volume
# group
# domotica   21330
