# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
onlyfiles = [f for f in listdir('../data') if isfile(join('../data', f))]

# %%
def create_df(files):
    for index, file in enumerate(onlyfiles):
        path = '../data/' + file
        if index == 0:
            df = pd.read_csv(path)
        else:
            df1 = pd.read_csv(path)
            df = pd.concat([df,df1])
    return df

# %%
df = create_df(onlyfiles)

# %%
df.drop(columns=['SERP Features', 'Trend'], inplace=True)

# %%
df = df[df.Volume > 100]

# %%
df = df.sort_values(by=['Volume'], ascending=False)

# %%
words_list = ['genshin', 'honey', 'energía xxi', 'fenie', 'chc', 'deep', 'honkai', 'tna', 'agencia', 'game', 'subito', 'muebles', 'nike', 
              'súbito', 'canarias', 'periódico', 'carrefour', 'dibujo', 'edp', 'endesa', 'guru', 'periodico', 'próxima', 'repsol', 'cooperativa',
              'energes', 'gana']

# %%
def remove_rows(df, list):
    for word in list:
        df = df[df["Keyword"].str.contains(word) == False]
    return df

# %%
df = remove_rows(df, words_list)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                  Keyword  Volume  Keyword Difficulty  CPC (USD)  \
# 0             aerotermia   33100                53.0       0.33
# 1           ahorro total   14800                42.0       0.26
# 2         medio ambiente   12100                79.0       0.70
# 3             ahorra mas    9900                42.0       0.44
# 4  eficiencia energetica    6600                61.0       0.41
#
#    Competitive Density  Number of Results                        Intent
# 0                 1.00       4.350000e+06  Informational, Transactional
# 1                 1.00       8.290000e+07                  Navigational
# 2                 0.01       1.320000e+09                 Informational
# 3                 0.01       7.220000e+07                  Navigational
# 4                 0.18       6.160000e+06     Informational, Commercial

# %%
df_35 = df.head(35)
df_35
# Out:
#                            Keyword  Volume  Keyword Difficulty  CPC (USD)  \
# 0                       aerotermia   33100                53.0       0.33
# 1                     ahorro total   14800                42.0       0.26
# 2                   medio ambiente   12100                79.0       0.70
# 3                       ahorra mas    9900                42.0       0.44
# 4            eficiencia energetica    6600                61.0       0.41
# 5            eficiencia energetica    6600                61.0       0.41
# 6                       eficiencia    6600                55.0       0.22
# 7              energías renovables    6600                62.0       0.47
# 8                aerotermia precio    5400                30.0       0.44
# 9              como ahorrar dinero    4400                39.0       0.29
# 10               energía renovable    4400                63.0       0.47
# 11                   energía solar    4400                58.0       1.18
# 12                         energía    3600                84.0       0.79
# 13                          energí    3600                93.0       0.65
# 14            que es la aerotermia    3600                47.0       0.17
# 15                         ahorrar    3600                43.0       0.55
# 16                          ahorro    3600                57.0       0.55
# 17               el medio ambiente    2900                68.0       0.70
# 18           eficiencia energética    2900                68.0       0.41
# 19                 energía nuclear    2900                56.0       0.06
# 20                  energía eólica    2900                49.0       0.34
# 21               aerotermia que es    2900                44.0       0.17
# 22              aerotermia precios    2900                32.0       0.44
# 23       aerotermia con radiadores    2900                24.0       0.39
# 24        aerotermia como funciona    2900                45.0       0.18
# 25           eficiencia energética    2900                68.0       0.41
# 26                       eficiente    2900                50.0       0.22
# 27           eficiencia y eficacia    2900                44.0       0.12
# 28              energía geotérmica    2400                36.0       0.16
# 29                          impact    2400                65.0       4.80
# 30                         impacto    2400                61.0       0.00
# 31                energía cinética    2400                45.0       0.54
# 32  medioambiente o medio ambiente    2400                39.0       0.00
# 33  medio ambiente o medioambiente    2400                39.0       0.00
# 34  dia mundial del medio ambiente    2400                63.0       0.75
#
#     Competitive Density  Number of Results                        Intent
# 0                  1.00       4.350000e+06  Informational, Transactional
# 1                  1.00       8.290000e+07                  Navigational
# 2                  0.01       1.320000e+09                 Informational
# 3                  0.01       7.220000e+07                  Navigational
# 4                  0.18       6.160000e+06     Informational, Commercial
# 5                  0.18       6.160000e+06     Informational, Commercial
# 6                  0.00       2.370000e+08                 Informational
# 7                  0.20       3.100000e+07                 Informational
# 8                  1.00       2.320000e+06                 Transactional
# 9                  0.29       6.040000e+07                 Informational
# 10                 0.20       1.780000e+07                 Informational
# 11                 0.69       7.860000e+07                    Commercial
# 12                 0.04       6.940000e+08                 Informational
# 13                 0.02       1.360000e+09                    Commercial
# 14                 0.65       4.420000e+06                 Informational
# 15                 0.07       1.200000e+08                 Informational
# 16                 0.07       3.200000e+08                    Commercial
# 17                 0.01       1.220000e+09                 Informational
# 18                 0.18       2.790000e+07                 Informational
# 19                 0.01       2.330000e+07                 Informational
# 20                 0.22       1.020000e+07                 Informational
# 21                 0.65       3.860000e+06                 Informational
# 22                 1.00       2.040000e+06                 Transactional
# 23                 1.00       2.110000e+06  Informational, Transactional
# 24                 0.61       2.160000e+05                 Informational
# 25                 0.18       2.790000e+07                 Informational
# 26                 0.00       4.380000e+08  Informational, Transactional
# 27                 0.01       4.740000e+07                 Informational
# 28                 0.05       2.540000e+06                 Informational
# 29                 0.08       6.860000e+09                  Navigational
# 30                 0.04       1.120000e+09                    Commercial
# 31                 0.00       7.270000e+06                 Informational
# 32                 0.00       2.220000e+07                 Informational
# 33                 0.00       2.250000e+07                 Informational
# 34                 0.02       1.250000e+08                 Informational

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df_35, x="Volume", y="Keyword")
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Keyword'>

# %%
def keep_rows(df, word):
    df = df[df["Keyword"].str.contains(word)]
    return df

# %%
df_aerotermia = keep_rows(df, 'aerotermia')
df_aerotermia['group'] = 'aerotermia'
df_aerotermia = df_aerotermia.groupby(['group']).sum('Volume')
df_aerotermia = df_aerotermia[['Volume']]
df_aerotermia
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# aerotermia  164770

# %%
df_eficiencia = keep_rows(df, 'eficiencia')
df_eficiencia['group'] = 'eficiencia'
df_eficiencia = df_eficiencia.groupby(['group']).sum('Volume')
df_eficiencia = df_eficiencia[['Volume']]
df_eficiencia.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# eficiencia  139250

# %%
df_etiqueta = keep_rows(df, 'etiqueta')
df_etiqueta['group'] = 'etiqueta'
df_etiqueta = df_eficiencia.groupby(['group']).sum('Volume')
df_etiqueta = df_etiqueta[['Volume']]
df_etiqueta.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# eficiencia  139250

# %%
df_consumo = keep_rows(df, 'consumo')
df_consumo['group'] = 'consumo'
df_consumo = df_eficiencia.groupby(['group']).sum('Volume')
df_consumo = df_consumo[['Volume']]
df_consumo.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# eficiencia  139250

# %%
df_medioambiente = keep_rows(df, 'medio ambiente')
df_medioambiente['group'] = 'medio ambiente'
df_medioambiente = df_eficiencia.groupby(['group']).sum('Volume')
df_medioambiente = df_medioambiente[['Volume']]
df_medioambiente.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Volume
# group
# eficiencia  139250
