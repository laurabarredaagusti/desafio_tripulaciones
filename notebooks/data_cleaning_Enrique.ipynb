# %%
import pandas as pd

# %%
df_localspaceheaters = pd.read_csv('../data_product_groups/solid_fuiel_boiler.csv')

# %%
df_localspaceheaters = pd.read_csv('../data_product_groups/localspaceheaters.csv')

# %%
df_localspaceheaters.head()
# Out:
#                                                 Type         Title  \
# 0                        BESTAR INDUSTRIAL CO.,LTD.    PTC-1500TR
# 1                        BESTAR INDUSTRIAL CO.,LTD.    PTC-1500P1
# 2   Dongguan Luying Plastic Hardware Products Co....    YND-2000D
# 3                                       FULMO/IPG31     309020101
# 4                                       FULMO/IPB30     309020102
#
#                eclrow Content               eclrow3 eclrow4  \
# 0  Direct heat output     1,5  Indirect heat output       -
# 1  Direct heat output     1,2  Indirect heat output       -
# 2  Direct heat output     1,9  Indirect heat output       -
# 3  Direct heat output     4,2  Indirect heat output       -
# 4  Direct heat output     4,2  Indirect heat output       -
#
#                    eclrow5  Content6  \
# 0  Energy Efficiency Index       116
# 1  Energy Efficiency Index       110
# 2  Energy Efficiency Index       114
# 3  Energy Efficiency Index        91
# ...

# %%
df_solid_fuiel_boiler = pd.read_csv('../data_product_groups/solid_fuiel_boiler.csv')

# %%
df_solid_fuiel_boiler.head()
# Out:
#           Type         Title             eclrow  Content  \
# 0   Paradigma       05-5834   Rated heat output       32
# 1   Paradigma       05-5832   Rated heat output       25
# 2   Paradigma       05-5831   Rated heat output       22
# 3   Paradigma       05-5833   Rated heat output       28
# 4   Edilkamin    EXPERTA 27   Rated heat output       24
#
#                          eclrow3  Content4  \
# 0  Energy efficiency index (EEI)       119
# 1  Energy efficiency index (EEI)       118
# 2  Energy efficiency index (EEI)       118
# 3  Energy efficiency index (EEI)       119
# 4  Energy efficiency index (EEI)       121
#
#                                                Image
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# 3  https://eprel.ec.europa.eu/assets/images/label...
# 4  https://eprel.ec.europa.eu/assets/images/label...

# %%
df_tumble_driers = pd.read_csv('../data_product_groups/tumble_driers.csv')

# %%
df_tumble_driers.head()
# Out:
#         Type           Title                             eclrow2 Content  \
# 0   Samsung    DV90BB9545GM   Weighted Annual Energy Consumption     176
# 1     Bosch      WTH85VSXPL   Weighted Annual Energy Consumption     236
# 2   Siemens      WT45HVU5AT   Weighted Annual Energy Consumption     236
# 3     Bosch      WTH85200FG   Weighted Annual Energy Consumption     236
# 4     Bosch      WTH85VU5AT   Weighted Annual Energy Consumption     236
#
#                                  eclualignitemslgend eclualignitemslgend5  \
# 0  Programme time of the ‘standard cotton program...                 3:59
# 1  Programme time of the ‘standard cotton program...                 3:25
# 2  Programme time of the ‘standard cotton program...                 3:25
# 3  Programme time of the ‘standard cotton program...                 3:25
# 4  Programme time of the ‘standard cotton program...                 3:25
#
#                                                Image
# ...

# %%
de_ventilation_units= pd.read_csv('../data_product_groups/ventilation_units.csv')

# %%
de_ventilation_units.head()
# Out:
#                     Type               Title                         eclrow2  \
# 0   Mitsubishi Electric    VL-250CZPVU-R-EG   Annual Electricity Consumption
# 1   Mitsubishi Electric    VL-250CZPVU-L-EG   Annual Electricity Consumption
# 2   Mitsubishi Electric    VL-500CZPVU-R-EG   Annual Electricity Consumption
# 3   Mitsubishi Electric    VL-500CZPVU-L-EG   Annual Electricity Consumption
# 4            Kermi GmbH      x-well F270 LH   Annual Electricity Consumption
#
#   Content            eclrow5 Content6  \
# 0     1,9  Maximum flow rate      265
# 1     1,9  Maximum flow rate      265
# 2       2  Maximum flow rate      530
# 3       2  Maximum flow rate      530
# 4     271  Maximum flow rate      270
#
#                                                Image
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# 3  https://eprel.ec.europa.eu/assets/images/label...
# ...

# %%
de_washer_dryer= pd.read_csv('../data_product_groups/washer_dryers(2).csv')

# %%
de_washer_dryer.head()
# Out:
#    Unnamed: 0        Brand                  Model  \
# 0           0   WHIRLPOOL    FFWDB 864369 BV SPT
# 1           1     INDESIT       BDE 76435 9W SPT
# 2           2     INDESIT      BDE 86435 9WS SPT
# 3           3       Bosch             WNA13401CH
# 4           4   WHIRLPOOL    FFWDB 964369 BV SPT
#
#                                       Contenido2  Consumo en Ciclo Completo  \
# 0  Consumo de energía ponderado (por 100 ciclos)                        307
# 1  Consumo de energía ponderado (por 100 ciclos)                        307
# 2  Consumo de energía ponderado (por 100 ciclos)                        307
# 3  Consumo de energía ponderado (por 100 ciclos)                        322
# 4  Consumo de energía ponderado (por 100 ciclos)                        307
#
#                                 Label Ciclo Completo  \
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# ...

# %%
de_washer_dryer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650 entries, 0 to 1649
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1650 non-null   int64
#  1   Brand                       1650 non-null   object
#  2   Model                       1650 non-null   object
#  3   Contenido2                  1650 non-null   object
#  4   Consumo en Ciclo Completo   1650 non-null   int64
#  5   Label Ciclo Completo        1650 non-null   object
#  6   Consumo en Ciclo de Lavado  1650 non-null   int64
#  7   Label Ciclo de Lavado       1650 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 103.2+ KB

# %%
df_water_heaters = pd.read_csv('../data_product_groups/water_heaters.csv')

# %%
df_water_heaters.head()
# Out:
#         Type                 Title                         eclrow15 Content16  \
# 0   Rossato     AIR COMBO EVO 300   Annual electricity consumption      1 361
# 1   Rossato    AIR COMBO EVO 200S   Annual electricity consumption        890
# 2   Rossato     AIR COMBO EVO 200   Annual electricity consumption        890
# 3   Rossato    AIR COMBO EVO 300S   Annual electricity consumption      1 361
# 4   CORBERO          CCEP110GNNOX           Annual fuel consumption         6
#
#                           eclrow11 Content12  \
# 0  Water heating energy efficiency       123
# 1  Water heating energy efficiency       115
# 2  Water heating energy efficiency       115
# 3  Water heating energy efficiency       123
# 4  Annual electricity consumption         21
#
#                                                Image
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# ...

# %%
df_dishwashers = pd.read_csv('../data_product_groups/dishwashers.csv')

# %%
df_dishwashers.head()
# Out:
#          Type            Title                                     eclrow  \
# 0     Iberna    IDIH 2L952-80   Rated capacity for the eco programme (ps)
# 1   Baumatic    BDIH 2L952-80   Rated capacity for the eco programme (ps)
# 2    Siemens       SN23HW00ME   Rated capacity for the eco programme (ps)
# 3      Bosch       SMS4HMI02E   Rated capacity for the eco programme (ps)
# 4    Siemens       SN23HI00KE   Rated capacity for the eco programme (ps)
#
#    Content                                            eclrow4 Content5  \
# 0        9  Energy consumption [per 100 cycles, based on t...       70
# 1        9  Energy consumption [per 100 cycles, based on t...       70
# 2       14  Energy consumption [per 100 cycles, based on t...       85
# 3       14  Energy consumption [per 100 cycles, based on t...       85
# 4       13  Energy consumption [per 100 cycles, based on t...       84
#
#                                                Image
# ...

# %%
df_washing_machines = pd.read_csv('../data_product_groups/washing_machines.csv')

# %%
df_washing_machines.head()
# Out:
#         Type           Title  \
# 0     Bosch      WIW28302GB
# 1     Bosch      WAX32M02BY
# 2   Samsung    WW11BB945AGM
# 3    BRANDT    WFB814WP -01
# 4   Siemens      WG44G2A2FG
#
#                                              eclrow5  Content6  \
# 0  Weighted energy consumption [per 100 cycles, e...        62
# 1  Weighted energy consumption [per 100 cycles, e...        59
# 2  Weighted energy consumption [per 100 cycles, e...        48
# 3  Weighted energy consumption [per 100 cycles, e...        73
# 4  Weighted energy consumption [per 100 cycles, e...        46
#
#                                                Image
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# 3  https://eprel.ec.europa.eu/assets/images/label...
# 4  https://eprel.ec.europa.eu/assets/images/label...

# %%
df_washing_machines['eclrow5'][0]
# Out:
# 'Weighted energy consumption [per 100 cycles, eco 40-60 programme]'

# %%
df_campanas_extractoras = pd.read_csv('../data_product_groups/campanas_extractoras.csv')

# %%
df_campanas_extractoras.head()
# Out:
#          Brand             Model  \
# 0      Pitsos           2MID60T
# 1    HOTPOINT    PHBS9.8CLTDK/1
# 2         MPM     MPM-90-OVS-24
# 3   WHIRLPOOL     WHVF 92F LT K
# 4   WHIRLPOOL     WHVF 62F LT K
#
#                                               Imagen  \
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# 3  https://eprel.ec.europa.eu/assets/images/label...
# 4  https://eprel.ec.europa.eu/assets/images/label...
#
#                   Contenido Contenido1 Contenido2 Contenido10  Contenido11  \
# 0  Consumo anual de energía       37,9   kWh/año        Ruido           53
# 1  Consumo anual de energía       49,3   kWh/año        Ruido           70
# 2  Consumo anual de energía       53,4   kWh/año        Ruido           68
# 3  Consumo anual de energía         47   kWh/año        Ruido           62
# ...

# %%
df_fridges_and_freezers1 = pd.read_csv('../data_product_groups/fridges_and_freezers(1).csv')
df_fridges_and_freezers1.head()
# Out:
#         Type          Title ngstarinserted__divcontains_class_ecludnone  \
# 0     OCEAN     CB 290 W 2                    Annual energy consumption
# 1     IGNIS    CNFT365FWEU                    Annual energy consumption
# 2     IGNIS    CNFT365FSEU                    Annual energy consumption
# 3   Samsung    RL38A7B63WW                    Annual energy consumption
# 4   Samsung    RB34A7B4DS9                    Annual energy consumption
#
#   ngstarinserted__divcontains_class_ecludnone3  \
# 0                                          280
# 1                                          299
# 2                                          299
# 3                                          169
# 4                                          204
#
#                                             eclrow eclrow5  \
# 0  Sum of the volumes of the frozen compartment(s)      84
# 1  Sum of the volumes of the frozen compartment(s)      88
# 2  Sum of the volumes of the frozen compartment(s)      88
# ...

# %%
df_fridges_and_freezers1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Type                                          20000 non-null  object
#  1   Title                                         20000 non-null  object
#  2   ngstarinserted__divcontains_class_ecludnone   20000 non-null  object
#  3   ngstarinserted__divcontains_class_ecludnone3  20000 non-null  object
#  4   eclrow                                        20000 non-null  object
#  5   eclrow5                                       20000 non-null  object
#  6   eclrow7                                       20000 non-null  object
#  7   Content8                                      20000 non-null  object
#  8   eclrow9                                       20000 non-null  object
# ...

# %%
df_fridges_and_freezers2 = pd.read_csv('../data_product_groups/fridges_and_freezers(2).csv')
df_fridges_and_freezers2.head()
# Out:
#           Type             Title ngstarinserted__divcontains_class_ecludnone  \
# 0   Blaupunkt         5CF350FF1                    Annual energy consumption
# 1     Oceanic       OCEACUF188W                    Annual energy consumption
# 2      Kernau    KFUF 08252.1 W                    Annual energy consumption
# 3      COLDIS         CODP206A+                    Annual energy consumption
# 4    WESTWOOD          WRC268-1                    Annual energy consumption
#
#   ngstarinserted__divcontains_class_ecludnone3  \
# 0                                       219,37
# 1                                          246
# 2                                          213
# 3                                          213
# 4                                          277
#
#                                             eclrow eclrow5  \
# 0  Sum of the volumes of the frozen compartment(s)      15
# 1  Sum of the volumes of the frozen compartment(s)     188
# ...

# %%
df_fridges_and_freezers2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8266 entries, 0 to 8265
# Data columns (total 10 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Type                                          8266 non-null   object
#  1   Title                                         8266 non-null   object
#  2   ngstarinserted__divcontains_class_ecludnone   8266 non-null   object
#  3   ngstarinserted__divcontains_class_ecludnone3  8266 non-null   object
#  4   eclrow                                        8266 non-null   object
#  5   eclrow5                                       8266 non-null   object
#  6   eclrow7                                       8266 non-null   object
#  7   Content8                                      8266 non-null   object
#  8   eclrow9                                       8266 non-null   object
# ...

# %%
df_hotwaterstoragetanks = pd.read_csv('../data_product_groups/hotwaterstoragetanks.csv')
df_hotwaterstoragetanks.head()
# lo quitamos de la lista!!!!!!!!
# Out:
#                Type                     Title         eclrow  Content  \
# 0             ELÍZ               EURO 500 D1   Standing loss       71
# 1             ELÍZ               EURO 300 D1   Standing loss       50
# 2   Itho Daalderop    03-00673 I-WPV 150L 3G   Standing loss       26
# 3   Itho Daalderop      03-00667 WPV 150L 3G   Standing loss       26
# 4   Itho Daalderop      03-00668 WPV 200L 3G   Standing loss       37
#
#           eclrow2  Content3   eclrow5  \
# 0  Storage volume       441   Liters
# 1  Storage volume       249   Liters
# 2  Storage volume       150   Liters
# 3  Storage volume       150   Liters
# 4  Storage volume       200   Liters
#
#                                                Image
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# 3  https://eprel.ec.europa.eu/assets/images/label...
# ...

# %%
df_professionalrefrigeratedstoragecabinets = pd.read_csv('../data_product_groups/professionalrefrigeratedstoragecabinets.csv')
df_professionalrefrigeratedstoragecabinets.head()
# Out:
#          Type           Title                     eclrow Content      eclrow2  \
# 0     Amitek     AK2102-10TN   Annual energy consumption     628   kWh/annum
# 1     Amitek     AK2102-11TN   Annual energy consumption     628   kWh/annum
# 2     Amitek    AKT4206-18TN   Annual energy consumption   1 332   kWh/annum
# 3     Amitek    AKT4206-10TN   Annual energy consumption   1 332   kWh/annum
# 4   Coolhead         QR 6-5A   Annual energy consumption     309   kWh/annum
#
#             eclrow3 eclrow5   eclrow6          eclrow7 eclrow8        eclrow9  \
# 0  Volume (Chilled)     190   Liters   Volume (Frozen)       0  Climate class
# 1  Volume (Chilled)     190   Liters   Volume (Frozen)       0  Climate class
# 2  Volume (Chilled)     376   Liters   Volume (Frozen)       0  Climate class
# 3  Volume (Chilled)     376   Liters   Volume (Frozen)       0  Climate class
# 4  Volume (Chilled)     410   Liters   Volume (Frozen)       0  Climate class
#
# ...

# %%
df_televisions_monitors_others = pd.read_csv('../data_product_groups/televisions_monitors_others.csv')
df_televisions_monitors_others.head()
# Out:
#                   Marca          Modelo  \
# 0   IIYAMA CORPORATION    GB2770HSU-B5
# 1   IIYAMA CORPORATION       B1980D-B5
# 2   IIYAMA CORPORATION       B1980D-W5
# 3   IIYAMA CORPORATION    GB2470HSU-B5
# 4   IIYAMA CORPORATION     XB2481HS-B5
#
#                                               Imagen  \
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# 2  https://eprel.ec.europa.eu/assets/images/label...
# 3  https://eprel.ec.europa.eu/assets/images/label...
# 4  https://eprel.ec.europa.eu/assets/images/label...
#
#   Consumo_en_modo_encendido_en_el_rango_dinámico_normal_SDR  \
# 0                                               18,8
# 1                                               14,5
# 2                                               14,5
# 3                                               18,6
# 4                                               17,6
#
# ...

# %%
import pandas as pd

# %%
df_washer_dryers2 = pd.read_csv('../data_product_groups/washer_dryers(2).csv')
df_washer_dryers2.head()
# Out:
#    Unnamed: 0        Brand                  Model  \
# 0           0   WHIRLPOOL    FFWDB 864369 BV SPT
# 1           1     INDESIT       BDE 76435 9W SPT
# 2           2     INDESIT      BDE 86435 9WS SPT
# 3           3       Bosch             WNA13401CH
# 4           4   WHIRLPOOL    FFWDB 964369 BV SPT
#
#                                       Contenido2  Consumo en Ciclo Completo  \
# 0  Consumo de energía ponderado (por 100 ciclos)                        307
# 1  Consumo de energía ponderado (por 100 ciclos)                        307
# 2  Consumo de energía ponderado (por 100 ciclos)                        307
# 3  Consumo de energía ponderado (por 100 ciclos)                        322
# 4  Consumo de energía ponderado (por 100 ciclos)                        307
#
#                                 Label Ciclo Completo  \
# 0  https://eprel.ec.europa.eu/assets/images/label...
# 1  https://eprel.ec.europa.eu/assets/images/label...
# ...
